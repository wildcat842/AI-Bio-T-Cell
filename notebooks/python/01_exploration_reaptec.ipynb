# %% [markdown]
# # 01 - ReapTEC Atlas 초기 탐색
#
# 전제: `datasets/01_reaptec_atlas/processed/`에 enhancer BED 파일이 있음.
# 다운로드: `bash datasets/01_reaptec_atlas/scripts/download_processed.sh`

# %%
from aibio.data import ReapTECLoader
from aibio.utils import get_logger, set_seed
set_seed(42)
log = get_logger(__name__)
loader = ReapTECLoader.from_catalog()
log.info('ReapTEC loader: %s', loader)
log.info('BED path: %s', loader.enhancers_bed())

# %% [markdown]
# ## 다음 단계
#
# - BED 로드 → pandas DataFrame
# - 길이 분포·염색체 분포 EDA
# - GWAS overlap (`datasets/16_gwas_catalog_immune/`)
